# %% [markdown]
# # Coursera "IBM Applied Data Science Capstone" Project -- Week 5

# %% [markdown]
# ## Best Neighborhood to Operate a Restaurant in Amsterdam

# %% [markdown]
# ### Introduction:

# %% [markdown]
# This project is a "Capstone Project" of Coursera - "IBM Applied Data Science Capstone Course" in the fourth/fifth weeks. In this project, we want to determine the best neighborhood in Amsterdam for the entrepreneurs to open a new restaurant. In the project, we tried to use most of the python scripts, libraries, virtualization of data, foursquare api.. etc.
#
# Please, pay attention!... It is only a capstone final project and it is not claimed that the result of the project is 100% proper for trade and investing industry. On the other hand, it can be helpful in the decision process for the entrepreneurs and/or give an idea to make a comprehensive project to researchers.

# %% [markdown]
# ### Description and Background of the Problem:

# %% [markdown]
# While starting the project, like in course duration, we decided to analyse an other famous, important and crowded city, Amsterdam. As we know Amsterdam is the capital city of Netherlands. We also learn from <a href="https://nl.wikipedia.org/wiki/Amsterdam">wikipedia</a>; "_the municipality of Amsterdam has 863,202 inhabitants (1 January 2019, CBS ). On the other hand, it is the fourth most visited city in Europe, around 17 million day trippers come to Amsterdam every year. Among the tourists are also many other museums , the coffee shops , __the restaurants__ and window prostitution in the Wallen (Red Light District) popular. The falling number of cafés is offset by a __sharply increasing number of restaurants since 2010__, not only in the center but also in the surrounding districts._"
#
# As we know, choosing a neighborhood and location for a restaurant is an important and diffucult step for the entrepreneurs. Most of time it can be as crucial factor as menu quality and service for the restaurant's success. The neighborhood is not only an important factor for customers but also it affects the restaurant quality, including the menu, interior design, style of furnitures.
#
# So, the question (problem) is clear: <font color=red>Which neighborhood is suitable place for a new restaurant in Amsterdam?</font>
#
# For finding the answer of the question, first of all, we need the key factors of selecting the location for a restaurant. After making some search in open source (of course Google!), we found an article
# <a href="https://www.thebalancesmb.com/choosing-a-location-for-your-restaurant-2888635">"4 Important Factors When Choosing a Location to Open a Restaurant"</a>. The article explain the 4 important factor shortly, which are;
# - __Parking__<br>
# A restaurant should has its own parking lot. If that isn’t an option (for example, in a major cities), consider partnering with a hotel in the area that has its own parking options. Also it has an acceptable distance to public parking lots.
# - __Accessibility__<br>
# There’s a reason that major restaurant chains are often located near highway exits: It makes them accessible for customers. Also it is a good option to close distance to public transportations. Light Rail Station, Metro Station, Train/Tram Station, Bus Stop around the restaurant is provide convenience for customers.
# - __Visibility__<br>
# This goes along with accessibility and is very important for new restaurant locations. People have to know the restaurant is there, either in person or on their mobile devices.
# - __Population Base__<br>
# There need to be enough people who live in or pass through the area regularly to keep the restaurant busy. So "the particular area's population base" is another important factor about suitable place for a new restaurant.
#
# As we mentioned before, Amsterdam has a very crowded city with huge number of tourists. So we can eliminate the fourth factor (Population Base). The third factor (Visibility) is not easy to keep in view, because it needs different type of data like usage density of every streets, frequently prefered routas and the prefered reason... etc. May be a field research is also needed. Anyway, because of the diffuculties, we focused on first two factors (Parking and Accessibility) and collected data about them.

# %% [markdown]
# ### Description of the Data:

# %% [markdown]
# For solving the problem, it is clear that we need different type of data. Which are:
# 1. List of neighborhoods of Amsterdam
# 2. Car Parking list and their geolocations of Amsterdam
# 3. Light Rail/Metro/Train/Tram/Bus Station list and their geolocations of Amsterdam
#
# While searching in open source, we reach the "Statistics Netherlands" <a href="https://opendata.cbs.nl/#/CBS/en/navigatieScherm/thema"> (Centraal Bureau voor de Statistiek-CBS)</a> web site, where publishes formal, regular statistical datasets in various issues. we got the first and fourth datasets from there.
#
# The second and third datasets are POI and it is easy to reach them by Foursquare API. So we tried to get the data via Foursquare API.
#
# The important disadvantage of API is the response limit of queries. In every query, the response of venues list limited as 100 result. So, we tried to send query with sub-categoryIDs of venues' <a href="https://developer.foursquare.com/docs/resources/categories">(which is exist in Foursquare web site)</a> and update the dataframe with "for loop" easily. we explained this detail later also.

# %% [markdown]
# ### Table of Contents:

# %% [markdown]
# Introduction<br>
# Description and Background of the Problem<br>
# Description of the Data<br>
# The Steps of the Project<br>
# > 1) Download and Explore Dataset<br>
# > 2) Show Neighborhoods of Amsterdam on Map<br>
# > 3) Create DataSets For Comparison<br>
# > 4) Arrange The DataFrames<br>
# > 5) Comparison of Neighborhoods
#
# Result of the Project<br>
# Discussion about the Project<br>
# Conclusion of the Project<br>
# Presentation of the Project

# %% [markdown]
# ### The Steps of the Project:

# %% [markdown]
# First of, all we import the required libraries

# %%
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.distance import geodesic
from statistics import mean
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None # disable chained assignments
print('Required libraries imported.')
# Out:
# Required libraries imported.

# %% [markdown]
# #### 1. Download and Explore Dataset

# %% [markdown]
# For determining the best neighborhood in Amsterdam, first of all we need the boroughs and neighborhoods list of the Amsterdam. Also we need the latitude and logitude coordinates of each neighborhoods.
#
# After marking a small search on Google, we reach a public <a href="https://claircitydata.cbs.nl/dataset/689ded75-1a80-4259-b033-63913573c13a/resource/d02c5f12-1cfa-4d7c-91d3-41af8e4ed634/download/wijken_buurten.csv"> "Districts and Neighbourhoods Amsterdam"</a> dataset. It is free and public dataset that produced by the "Statistics Netherlands" <a href="https://opendata.cbs.nl/#/CBS/en/navigatieScherm/thema"> (Centraal Bureau voor de Statistiek-CBS)</a>.

# %%
filename = "https://claircitydata.cbs.nl/dataset/689ded75-1a80-4259-b033-63913573c13a/resource/d02c5f12-1cfa-4d7c-91d3-41af8e4ed634/download/wijken_buurten.csv"
#df_amsterdam_data= pd.read_csv(filename,delimiter=',')
df_amsterdam_data=pd.read_csv('wijken_buurten.csv',delimiter=',')
df_amsterdam_data.shape
# Out:
# (579, 37)

# %% [markdown]
# As we see the result, in dataset; 579 row and 37 column exist.<br>
# Firstly, we want know the details of data:

# %%
list(df_amsterdam_data.columns)
# Out:
# ['subject',
#  'region_name',
#  'regio_type',
#  'region_code',
#  'ninhabitants',
#  'nmen',
#  'nwomen',
#  'nage_0_to_15',
#  'nage_15_to_25',
#  'nage_25_to_45',
#  'nage_45_to_65',
#  'nage_65_older',
#  'nunmarried',
#  'nmarried',
#  'ndivorced',
#  'nwidowed',
#  'nimmigrant_western',
#  'nimmigrant_nonwestern',
#  'nimmigrant_marokko',
#  'nimmigrant_antiles_aruba',
#  'nimmigrant_surinam',
#  'nimmigrant_turkey',
#  'nimmigrant_other_non_western',
#  'nhouseholds',
#  'nhh_single_person',
#  'nhh_no_children',
#  'nhh_with_children',
#  'ave_househ_size',
#  'populatio_density',
#  'area_total',
#  'area_land',
#  'area_water',
#  'urbanisation_grade',
#  'address_density',
#  'geojson',
#  'lon',
#  'lat']

# %% [markdown]
# There is an important column exist which is named "regio_type". <br>
# So, we want to know the details of this data too

# %%
df_amsterdam_data['regio_type'].value_counts()
# Out:
# Buurt       479
# Wijk         99
# Gemeente      1
# Name: regio_type, dtype: int64

# %% [markdown]
# Secondly, we limit the "regio_type" with "Buurt" (__Neighborhood__)

# %%
df_amsterdam_data=df_amsterdam_data[df_amsterdam_data['regio_type']=='Buurt']
df_amsterdam_data.shape
# Out:
# (479, 37)

# %%
df_amsterdam_data.head()
# Out:
#            subject region_name regio_type region_code  ninhabitants  nmen  \
# 2      Kop Zeedijk   Amsterdam      Buurt  BU03630000          1020   570
# 3   Oude Kerk e.o.   Amsterdam      Buurt  BU03630001           670   365
# 4  Burgwallen Oost   Amsterdam      Buurt  BU03630002          1610   880
# 5         Nes e.o.   Amsterdam      Buurt  BU03630003           370   185
# 6  BG-terrein e.o.   Amsterdam      Buurt  BU03630004           605   330
#
#    nwomen  nage_0_to_15  nage_15_to_25  nage_25_to_45    ...      \
# 2     445            50            140            520    ...
# 3     300            30            130            320    ...
# 4     730           120            250            755    ...
# 5     180            25             70            195    ...
# 6     270            45             85            250    ...
#
#    ave_househ_size  populatio_density  area_total  area_land  area_water  \
# 2              1.4            16818.0           8          6           2
# 3              1.3             7615.0           9          9           0
# 4              1.4            25867.0           7          6           1
# 5              1.4             6939.0           6          5           0
# 6              1.4             7157.0          10          8           2
#
#    urbanisation_grade  address_density  \
# 2                 1.0           6649.0
# 3                 1.0           7361.0
# 4                 1.0           7544.0
# 5                 1.0           9825.0
# 6                 1.0           8428.0
#
#                                              geojson       lon        lat
# 2  {"type": "FeatureCollection","crs": { "type": ...  4.900280  52.375937
# 3  {"type": "FeatureCollection","crs": { "type": ...  4.896156  52.373793
# 4  {"type": "FeatureCollection","crs": { "type": ...  4.898757  52.372815
# 5  {"type": "FeatureCollection","crs": { "type": ...  4.893728  52.370861
# 6  {"type": "FeatureCollection","crs": { "type": ...  4.895584  52.369546
#
# [5 rows x 37 columns]

# %% [markdown]
# Then, after arrange the rows, we want to arrange the column too. <br>
# For focusing the column which we needs, we limited the columns with 'subject','region_name','lon','lat'.

# %%
df_amsterdam_data=df_amsterdam_data[['subject','region_name','lon','lat']]
df_amsterdam_data.head()
# Out:
#            subject region_name       lon        lat
# 2      Kop Zeedijk   Amsterdam  4.900280  52.375937
# 3   Oude Kerk e.o.   Amsterdam  4.896156  52.373793
# 4  Burgwallen Oost   Amsterdam  4.898757  52.372815
# 5         Nes e.o.   Amsterdam  4.893728  52.370861
# 6  BG-terrein e.o.   Amsterdam  4.895584  52.369546

# %% [markdown]
# Fourthly, we arrange the column names and reindex the dataframe
# Also, create 2 new columns, which we use them in the later on for comparing the neighborhoods

# %%
df_amsterdam_data.rename(columns={'subject': 'Neighborhood', 'region_name':'City','lon':'Longitude', 'lat':'Latitude'},inplace=True)
df_amsterdam_data['CarPark_Dist']=0
df_amsterdam_data['Close_Bus/Train']=0
df_amsterdam = df_amsterdam_data[['Neighborhood', 'City', 'Latitude','Longitude','CarPark_Dist','Close_Bus/Train']].reset_index(drop=True)
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280             0
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156             0
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757             0
# 3         Nes e.o.  Amsterdam  52.370861   4.893728             0
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584             0
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# That is all! The data (neighborhoods of Amsterdam) is ready...

# %% [markdown]
# #### 2. Show Neighborhoods of Amsterdam on Map

# %% [markdown]
# For showing the locations of Neighborhoods on map, we need the coordinate (latitude and longitude) of Amsterdam first. We use __geopy library__ to get the latitude and longitude values of Amsterdam.<br>
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent "_myapplication_", as shown below.

# %%
address = 'Amsterdam'
geolocator = Nominatim(user_agent="myapplication")
location = geolocator.geocode(address)
ams_latitude = location.latitude
ams_longitude = location.longitude
print(f'The geograpical coordinate of Amsterdam is: {ams_latitude}, {ams_longitude}')
# Out:
# The geograpical coordinate of Amsterdam is: 52.3745403, 4.89797550561798

# %% [markdown]
# Now, we can create a map of Amsterdam with neighborhoods.

# %%
# create map
map_amsterdam = folium.Map(location=[ams_latitude, ams_longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_amsterdam['Latitude'], df_amsterdam['Longitude'], df_amsterdam['City'], df_amsterdam['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_amsterdam)  
    
map_amsterdam
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3. Create DataSets For Comparison

# %% [markdown]
# We need 2 datasets for comparison between the neighborhoods. As we explained in "_Description of the Data_" section, we need;
# - Car Parking list and their geolocations of Amsterdam
# - Light Rail/Metro/Train/Tram/Bus Station list and their geolocations of Amsterdam<br>
#
# We can get these datas via Foursquare Api.
# Firstly, we establish the Foursquare Api.

# %%
CLIENT_ID =  1 # Foursquare ID
CLIENT_SECRET = 1  # Foursquare Secret
VERSION = '20180604'
LIMIT = 100 #response limit
print('Foursquare Credentails is:\nCLIENT ID\t:',CLIENT_ID,'\nCLIENT SECRET\t:',CLIENT_SECRET)
# Out:
# Foursquare Credentails is:
# CLIENT ID	: 1
# CLIENT SECRET	: 1

# %% [markdown]
# __DataSet of Parking Lots__
#
# We can reach __Parking Lots Locations__ via Foursquare Api with _Parking CategaoryId_. In <a href="https://developer.foursquare.com/docs/resources/categories">Foursquare</a> web site, we learned that the categoryId of Parking is "4c38df4de52ce0d596b336e1".

# %%
# some defination
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 3000 # define radius
categoryId='4c38df4de52ce0d596b336e1' #categoryId of Parking

#create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    ams_latitude, 
    ams_longitude, 
    radius,
    categoryId,
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=2FORA2OSPVYW5ZDJAQRNR0PIYKV5F1MLOPLTYJHFFLMQFSN3&client_secret=CAQJ0U1OTAE0HFYS3BOEPZVPMLRAQLZGJBIUSDN2LK43J5YW&v=20180604&ll=52.3745403,4.89797550561798&radius=3000&categoryId=4c38df4de52ce0d596b336e1&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d34b13f92e7a9002c2ff6a4'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Amsterdam',
#   'headerFullLocation': 'Amsterdam',
#   'headerLocationGranularity': 'city',
#   'query': 'parking',
#   'totalResults': 64,
#   'suggestedBounds': {'ne': {'lat': 52.40154032700003,
#     'lng': 4.94211922411202},
#    'sw': {'lat': 52.34754027299997, 'lng': 4.85383178712394}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531b3ef964a520208f27e3',
#        'name': 'Q-Park De Bijenkorf',
#        'location': {'address': 'Beursstraat 15',
#         'lat': 52.37413161763709,
#         'lng': 4.8945793955019345,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37413161763709,
#           'lng': 4.8945793955019345}],
#         'distance': 235,
#         'postalCode': '1012 JW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Beursstraat 15',
#          '1012 JW Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531b3ef964a520208f27e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5360b92b498ec21b527740b5',
#        'name': 'MobyPark - Parking Dam Square - Book now and pay only € 3/h!',
#        'location': {'address': 'Sint Jansstraat 8',
#         'crossStreet': 'NH Krasnapolsky',
#         'lat': 52.373077444399854,
#         'lng': 4.895562529563904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.373077444399854,
#           'lng': 4.895562529563904}],
#         'distance': 231,
#         'postalCode': '1012JS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Sint Jansstraat 8 (NH Krasnapolsky)',
#          '1012JS Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84900411'}},
#       'referralId': 'e-0-5360b92b498ec21b527740b5-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531ba9f964a5202a8f27e3',
#        'name': 'Q-Park De Kolk',
#        'location': {'address': 'Nieuwezijds Kolk 18',
#         'lat': 52.37626672185223,
#         'lng': 4.894437068895485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37626672185223,
#           'lng': 4.894437068895485}],
#         'distance': 307,
#         'postalCode': '1012 PV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwezijds Kolk 18',
#          '1012 PV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531ba9f964a5202a8f27e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e18470dfa761946458f2a0e',
#        'name': 'Parkeergarage Oosterdok',
#        'location': {'address': 'Oosterdoksstraat 150',
#         'lat': 52.37614737322475,
#         'lng': 4.909099528406037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37614737322475,
#           'lng': 4.909099528406037}],
#         'distance': 776,
#         'postalCode': '1011 DK',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterdoksstraat 150',
#          '1011 DK Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e18470dfa761946458f2a0e-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51791ae7e4b08571849ee488',
#        'name': 'Oosterdok Parking',
#        'location': {'address': 'Oosterdoksstraat 2',
#         'lat': 52.37656933569557,
#         'lng': 4.9052469479600305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37656933569557,
#           'lng': 4.9052469479600305}],
#         'distance': 543,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterdoksstraat 2', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51791ae7e4b08571849ee488-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb5ea56ef159c74102975f7',
#        'name': 'P1 Parking Amsterdam Centrum',
#        'location': {'address': 'Prins Hendrikkade 20a',
#         'lat': 52.37877902329827,
#         'lng': 4.896704459415858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37877902329827,
#           'lng': 4.896704459415858}],
#         'distance': 479,
#         'postalCode': '1012 TL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prins Hendrikkade 20a',
#          '1012 TL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb5ea56ef159c74102975f7-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5dbd8ff964a5205a6929e3',
#        'name': 'Parkeergarage Geelvinck',
#        'location': {'address': 'Singel 540',
#         'lat': 52.366379417488396,
#         'lng': 4.891984462738037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.366379417488396,
#           'lng': 4.891984462738037}],
#         'distance': 995,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 540', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5dbd8ff964a5205a6929e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c4d124498ecbc36a676063',
#        'name': 'ijdok',
#        'location': {'address': 'IJdok',
#         'lat': 52.3845,
#         'lng': 4.894828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3845,
#           'lng': 4.894828}],
#         'distance': 1129,
#         'postalCode': '1031',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok', '1031 Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c4d124498ecbc36a676063-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b98a72bf964a520344a35e3',
#        'name': 'Fietsflat',
#        'location': {'address': 'Stationsplein 17',
#         'crossStreet': 'Station Amsterdam Centraal',
#         'lat': 52.37922104923885,
#         'lng': 4.897032380104065,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37922104923885,
#           'lng': 4.897032380104065}],
#         'distance': 524,
#         'postalCode': '1012 AB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 17 (Station Amsterdam Centraal)',
#          '1012 AB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b98a72bf964a520344a35e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e37ad99483bda3eb1135431',
#        'name': 'Parking wijdesteeg',
#        'location': {'address': 'Wijdesteeg 5',
#         'lat': 52.37158801409718,
#         'lng': 4.889752326297164,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37158801409718,
#           'lng': 4.889752326297164}],
#         'distance': 648,
#         'postalCode': '1012 RN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Wijdesteeg 5',
#          '1012 RN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e37ad99483bda3eb1135431-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57befc3ccd1006b719394f99',
#        'name': 'Kiss+Ride',
#        'location': {'address': 'De Ruijterkade',
#         'crossStreet': 'at Station Amsterdam Centraal',
#         'lat': 52.380742,
#         'lng': 4.898545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.380742,
#           'lng': 4.898545}],
#         'distance': 691,
#         'postalCode': '1012',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['De Ruijterkade (at Station Amsterdam Centraal)',
#          '1012 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57befc3ccd1006b719394f99-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2d84e63a4d0f47ae14e486',
#        'name': 'Fietsplatform',
#        'location': {'address': 'De Ruyterkade',
#         'lat': 52.380918,
#         'lng': 4.898696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.380918,
#           'lng': 4.898696}],
#         'distance': 711,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['De Ruyterkade', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2d84e63a4d0f47ae14e486-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0372a1d3e364d5ffcc9a62',
#        'name': 'Parkeer Garage Waterloo',
#        'location': {'address': 'Waterlooplein',
#         'lat': 52.36928666195497,
#         'lng': 4.904278197005562,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36928666195497,
#           'lng': 4.904278197005562}],
#         'distance': 724,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Waterlooplein', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0372a1d3e364d5ffcc9a62-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c187d1dfe5a76b07c270215',
#        'name': 'ParkKing Waterlooplein',
#        'location': {'address': 'Valkenburgerstraat 238',
#         'lat': 52.36872357797005,
#         'lng': 4.903334162222304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36872357797005,
#           'lng': 4.903334162222304}],
#         'distance': 742,
#         'postalCode': '1011 ND',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Valkenburgerstraat 238',
#          '1011 ND Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c187d1dfe5a76b07c270215-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5000447ae4b06aae2cf280f9',
#        'name': 'De Overkant (van MdB)',
#        'location': {'address': 'Oude Turfmarkt',
#         'crossStreet': 'Rokin',
#         'lat': 52.36831510631523,
#         'lng': 4.893235543379496,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36831510631523,
#           'lng': 4.893235543379496}],
#         'distance': 764,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oude Turfmarkt (Rokin)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5000447ae4b06aae2cf280f9-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c658779f7a80f476c7d9b7a',
#        'name': 'Parkeergarage Stadhuis-Muziektheater',
#        'location': {'address': 'Waterlooplein 28',
#         'lat': 52.367373673154844,
#         'lng': 4.900237724647141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.367373673154844,
#           'lng': 4.900237724647141}],
#         'distance': 812,
#         'postalCode': '1011 PG',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Waterlooplein 28',
#          '1011 PG Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c658779f7a80f476c7d9b7a-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4995a3b73fb1f72e8ba932',
#        'name': 'Amstel',
#        'location': {'crossStreet': 'tussen Muntplein en Blauwbrug',
#         'lat': 52.36699194429201,
#         'lng': 4.897134304046631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36699194429201,
#           'lng': 4.897134304046631}],
#         'distance': 842,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amstel (tussen Muntplein en Blauwbrug)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4995a3b73fb1f72e8ba932-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eceb245e5faa5ec00d627f2',
#        'name': 'Parkking The Bank Rembrandtplein',
#        'location': {'address': 'Amstelstraat 2A',
#         'lat': 52.36597598308033,
#         'lng': 4.896660597040328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36597598308033,
#           'lng': 4.896660597040328}],
#         'distance': 957,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amstelstraat 2A', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eceb245e5faa5ec00d627f2-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb13a6275ebb60cbfc4cbad',
#        'name': 'Parkeergarage Markenhoven',
#        'location': {'address': 'Anne Frankstraat 220',
#         'lat': 52.37128803768359,
#         'lng': 4.911099204697603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37128803768359,
#           'lng': 4.911099204697603}],
#         'distance': 962,
#         'postalCode': '1011',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Anne Frankstraat 220',
#          '1011 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb13a6275ebb60cbfc4cbad-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fb9954498e63e51a99c35b',
#        'name': 'Fietsenstallingen Singel',
#        'location': {'address': 'Singel 471',
#         'lat': 52.367136067011565,
#         'lng': 4.89054948091507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.367136067011565,
#           'lng': 4.89054948091507}],
#         'distance': 966,
#         'postalCode': '1012 WP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 471', '1012 WP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fb9954498e63e51a99c35b-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52835db111d241cf1ef931f7',
#        'name': 'Parkeren Centrum / IJDock',
#        'location': {'address': 'IJdok 33',
#         'lat': 52.3840279222148,
#         'lng': 4.896115064620971,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3840279222148,
#           'lng': 4.896115064620971}],
#         'distance': 1063,
#         'postalCode': '1013MM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok 33', '1013MM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71516307'}},
#       'referralId': 'e-0-52835db111d241cf1ef931f7-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5968b397c0af5755e5e1ff0b',
#        'name': 'Interparking',
#        'location': {'address': 'IJdok 33',
#         'lat': 52.38485969,
#         'lng': 4.89473662,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38485969,
#           'lng': 4.89473662}],
#         'distance': 1169,
#         'postalCode': '1013 MM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok 33', '1013 MM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5968b397c0af5755e5e1ff0b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '591e84bd0802d4648116e86f',
#        'name': 'Piet Heingarage',
#        'location': {'address': 'Piet Heinkade 59',
#         'lat': 52.37762386,
#         'lng': 4.91486801,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37762386,
#           'lng': 4.91486801}],
#         'distance': 1198,
#         'postalCode': '1019 GM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Piet Heinkade 59',
#          '1019 GM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-591e84bd0802d4648116e86f-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae70c129deb7d00394652cb',
#        'name': 'ParkBee Keijzersgracht',
#        'location': {'address': 'Keizersgracht 485',
#         'lat': 52.3656351,
#         'lng': 4.88754734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3656351,
#           'lng': 4.88754734}],
#         'distance': 1218,
#         'postalCode': '1017 DL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Keizersgracht 485',
#          '1017 DL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ae70c129deb7d00394652cb-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df35a93aeb7170aa2f09c14',
#        'name': 'Parkeerplaats Artis',
#        'location': {'lat': 52.3681518748641,
#         'lng': 4.912996351128289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3681518748641,
#           'lng': 4.912996351128289}],
#         'distance': 1244,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df35a93aeb7170aa2f09c14-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ff1425f29a620cc99a98681',
#        'name': 'Willemspoort',
#        'location': {'address': 'Haarlemmer Houttuinen 549',
#         'lat': 52.38489743,
#         'lng': 4.88444376,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38489743,
#           'lng': 4.88444376}],
#         'distance': 1474,
#         'postalCode': '1013 GM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Haarlemmer Houttuinen 549',
#          '1013 GM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ff1425f29a620cc99a98681-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bc9adf964a520366e2fe3',
#        'name': 'Q-park Europarking',
#        'location': {'address': 'Marnixstraat 250',
#         'lat': 52.36984773836334,
#         'lng': 4.87711165052783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36984773836334,
#           'lng': 4.87711165052783}],
#         'distance': 1511,
#         'postalCode': '1016 TL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Marnixstraat 250',
#          '1016 TL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bc9adf964a520366e2fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d030755347da1cd9c2f238f',
#        'name': 'Parking De Hoofdstad',
#        'location': {'address': 'Prinsengracht 540',
#         'lat': 52.36428221385142,
#         'lng': 4.883124276541291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36428221385142,
#           'lng': 4.883124276541291}],
#         'distance': 1524,
#         'postalCode': '1017 KK',
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Prinsengracht 540', '1017 KK', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d030755347da1cd9c2f238f-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a15ea24db1d813177f5d274',
#        'name': 'Fietsenstalling Lijnbaansgracht',
#        'location': {'address': 'Lijnbaansgracht',
#         'lat': 52.36493141344514,
#         'lng': 4.8814982586373805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36493141344514,
#           'lng': 4.8814982586373805}],
#         'distance': 1548,
#         'postalCode': '1017 PH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lijnbaansgracht',
#          '1017 PH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a15ea24db1d813177f5d274-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c275465905a0f471aad6460',
#        'name': 'In de fontein!',
#        'location': {'address': 'Frederiksplein',
#         'lat': 52.360012400891705,
#         'lng': 4.899398367189806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.360012400891705,
#           'lng': 4.899398367189806}],
#         'distance': 1620,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Frederiksplein', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c275465905a0f471aad6460-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531af2f964a5201a8f27e3',
#        'name': 'Q-Park Byzantium',
#        'location': {'address': 'Tesselschadestraat 1G',
#         'lat': 52.36215291495878,
#         'lng': 4.879796086373648,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36215291495878,
#           'lng': 4.879796086373648}],
#         'distance': 1851,
#         'postalCode': '1054ET',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Tesselschadestraat 1G',
#          '1054ET Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531af2f964a5201a8f27e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d2072d85acaa35da1e6c735',
#        'name': 'Garage Nieuw Amerika',
#        'location': {'lat': 52.37602483886877,
#         'lng': 4.925883719129666,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37602483886877,
#           'lng': 4.925883719129666}],
#         'distance': 1903,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d2072d85acaa35da1e6c735-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c935da2f600236a7cb5c432',
#        'name': 'Furore parkeergarage',
#        'location': {'lat': 52.36466545425058,
#         'lng': 4.873930146116091,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36466545425058,
#           'lng': 4.873930146116091}],
#         'distance': 1969,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c935da2f600236a7cb5c432-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f3d02d498ef2bc889b0540',
#        'name': 'Q-Park Centrum Oost',
#        'location': {'address': 'Wibautstraat 3b',
#         'crossStreet': 'Tweede Boerhaavestraat',
#         'lat': 52.359955547241306,
#         'lng': 4.909160407386553,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.359955547241306,
#           'lng': 4.909160407386553}],
#         'distance': 1792,
#         'postalCode': '1091 GH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Wibautstraat 3b (Tweede Boerhaavestraat)',
#          '1091 GH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '521380742'}},
#       'referralId': 'e-0-55f3d02d498ef2bc889b0540-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ab0fb556f706a0fc7ed0cdc',
#        'name': 'ParkBee Van Beuningenstraat',
#        'location': {'address': 'Van Beuningenstraat 92',
#         'lat': 52.38334279,
#         'lng': 4.87570469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38334279,
#           'lng': 4.87570469}],
#         'distance': 1802,
#         'postalCode': '1051 XS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Van Beuningenstraat 92',
#          '1051 XS Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ab0fb556f706a0fc7ed0cdc-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f1ddb2fe4b03543a3cbcb38',
#        'name': 'Garage De Loodsen',
#        'location': {'address': 'Withoedenveem',
#         'lat': 52.37652668298653,
#         'lng': 4.924632397359297,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37652668298653,
#           'lng': 4.924632397359297}],
#         'distance': 1825,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Withoedenveem', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f1ddb2fe4b03543a3cbcb38-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ab11c07e1f22871bf0bd2e1',
#        'name': 'ParkBee Overtoom',
#        'location': {'address': 'Tweede Constantijn Huygensstraat 4',
#         'lat': 52.36433555,
#         'lng': 4.8720409,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36433555,
#           'lng': 4.8720409}],
#         'distance': 2097,
#         'postalCode': '1054 CT',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Tweede Constantijn Huygensstraat 4',
#          '1054 CT Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ab11c07e1f22871bf0bd2e1-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f43fea498e4fd0f060ce3b',
#        'name': 'Q-Park Weesperplein',
#        'location': {'address': 'Eerste Boerhaavestraat',
#         'crossStreet': 'Wibautstraat',
#         'lat': 52.35872206590383,
#         'lng': 4.908000889224843,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.35872206590383,
#           'lng': 4.908000889224843}],
#         'distance': 1888,
#         'postalCode': '1091 GM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Eerste Boerhaavestraat (Wibautstraat)',
#          '1091 GM Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f43fea498e4fd0f060ce3b-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59e85f790e5da854563fafc2',
#        'name': 'Q-Park Museumplein Bus',
#        'location': {'address': 'Paulus Potterstraat 1',
#         'lat': 52.3593443,
#         'lng': 4.8832149,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3593443,
#           'lng': 4.8832149}],
#         'distance': 1966,
#         'postalCode': '1071 CX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Paulus Potterstraat 1',
#          '1071 CX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59e85f790e5da854563fafc2-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a34445498e9013ad22b760',
#        'name': 'Parkeergarage Museum Quarter',
#        'location': {'address': 'Nicolaas Maesstraat 2D',
#         'lat': 52.355713802555236,
#         'lng': 4.88583174881569,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.355713802555236,
#           'lng': 4.88583174881569}],
#         'distance': 2252,
#         'postalCode': '1071 RA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nicolaas Maesstraat 2D',
#          '1071 RA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a34445498e9013ad22b760-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd17e22183899ddfb1dbbe6',
#        'name': 'Fietspunt Paradiso',
#        'location': {'address': 'Weteringschans',
#         'crossStreet': 'Leidseplein',
#         'lat': 52.36248370894872,
#         'lng': 4.8837578679781775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36248370894872,
#           'lng': 4.8837578679781775}],
#         'distance': 1653,
#         'postalCode': '1017',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Weteringschans (Leidseplein)',
#          '1017 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd17e22183899ddfb1dbbe6-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ecfcb2e775bbb5f321faafa',
#        'name': 'AOC Parkeergarage',
#        'location': {'address': 'WG Plein',
# ...
#        'location': {'address': 'Polderweg 92',
#         'lat': 52.3573113077506,
#         'lng': 4.927997812628746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3573113077506,
#           'lng': 4.927997812628746}],
#         'distance': 2800,
#         'postalCode': '1093 KP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Polderweg 92',
#          '1093 KP Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5723351b498e96aa8da224d4-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c505a6d67a9fe002cef23fb',
#        'name': 'ParkBee WestCord Art Hotel',
#        'location': {'address': 'Spaarndammerdijk 302',
#         'lat': 52.39270082,
#         'lng': 4.86844384,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.39270082,
#           'lng': 4.86844384}],
#         'distance': 2848,
#         'postalCode': '1013 ZX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spaarndammerdijk 302',
#          '1013 ZX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c505a6d67a9fe002cef23fb-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58cc51e8f857244e3890165c',
#        'name': 'Parking @ Hampton by Hilton',
#        'location': {'address': 'Borneolaan 1',
#         'lat': 52.3711762471736,
#         'lng': 4.934841002810463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3711762471736,
#           'lng': 4.934841002810463}],
#         'distance': 2533,
#         'postalCode': '1019HW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Borneolaan 1', '1019HW Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58cc51e8f857244e3890165c-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6ffa45f964a52017022de3',
#        'name': 'Cition',
#        'location': {'address': 'Nieuwpoortstraat 5',
#         'lat': 52.38408557186208,
#         'lng': 4.859052472363131,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38408557186208,
#           'lng': 4.859052472363131}],
#         'distance': 2850,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwpoortstraat 5', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6ffa45f964a52017022de3-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d91a5e7608fa1cd88409c83',
#        'name': 'Rhebergen Multihull Yachts',
#        'location': {'address': 'Tt. Neveritaweg 23-27',
#         'lat': 52.40121053341491,
#         'lng': 4.897621716259533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.40121053341491,
#           'lng': 4.897621716259533}],
#         'distance': 2968,
#         'postalCode': '1033 RC',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Tt. Neveritaweg 23-27',
#          '1033 RC Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d91a5e7608fa1cd88409c83-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d957d58a2c654814bb1a853',
#        'name': 'Hotel Notting Hill',
#        'location': {'address': 'Westeinde 26',
#         'lat': 52.35831989584969,
#         'lng': 4.899134201819135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.35831989584969,
#           'lng': 4.899134201819135}],
#         'distance': 1807,
#         'postalCode': '1017 ZP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Westeinde 26',
#          '1017 ZP Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d957d58a2c654814bb1a853-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9ff646f964a520f44d37e3',
#        'name': 'Dam',
#        'location': {'address': 'Dam',
#         'lat': 52.372824,
#         'lng': 4.893702,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.372824,
#           'lng': 4.893702}],
#         'distance': 347,
#         'postalCode': '1012 NP',
#         'cc': 'NL',
#         'neighborhood': 'Stadsdeel Centrum',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Dam', '1012 NP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9ff646f964a520f44d37e3-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '533e6157498e7c8639bcece0',
#        'name': 'De Hallen',
#        'location': {'address': 'Hannie Dankbaar Passage 47',
#         'lat': 52.366832338021034,
#         'lng': 4.8688868799837035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.366832338021034,
#           'lng': 4.8688868799837035}],
#         'distance': 2155,
#         'postalCode': '1053 RT',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Hannie Dankbaar Passage 47',
#          '1053 RT Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d171941735',
#          'name': 'Event Space',
#          'pluralName': 'Event Spaces',
#          'shortName': 'Event Space',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-533e6157498e7c8639bcece0-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c164d43a5eb76b05895c4b7',
#        'name': 'Kalverstraat',
#        'location': {'address': 'Kalverstraat',
#         'lat': 52.369612283931545,
#         'lng': 4.8911744356155396,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.369612283931545,
#           'lng': 4.8911744356155396}],
#         'distance': 717,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Kalverstraat', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1f9931735',
#          'name': 'Road',
#          'pluralName': 'Roads',
#          'shortName': 'Road',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c164d43a5eb76b05895c4b7-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7e0413f964a5202bdf2fe3',
#        'name': 'Max Euweplein',
#        'location': {'address': 'Max Euweplein',
#         'lat': 52.36229717189866,
#         'lng': 4.882841842562041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36229717189866,
#           'lng': 4.882841842562041}],
#         'distance': 1707,
#         'postalCode': '1017 MA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Max Euweplein',
#          '1017 MA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7e0413f964a5202bdf2fe3-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0e7e08f964a520fd5723e3',
#        'name': 'Van den Ende & Deitmers',
#        'location': {'address': 'Johannes Vermeerstraat 23',
#         'lat': 52.35719500031611,
#         'lng': 4.88458637691677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.35719500031611,
#           'lng': 4.88458637691677}],
#         'distance': 2134,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Johannes Vermeerstraat 23',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d124941735',
#          'name': 'Office',
#          'pluralName': 'Offices',
#          'shortName': 'Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0e7e08f964a520fd5723e3-58'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9eb62ff964a520ee3a20e3',
#        'name': 'De Duif',
#        'location': {'address': 'Prinsengracht 756',
#         'lat': 52.36138277821392,
#         'lng': 4.8967524602568915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36138277821392,
#           'lng': 4.8967524602568915}],
#         'distance': 1467,
#         'postalCode': '1017 LD',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prinsengracht 756',
#          '1017 LD Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a9eb62ff964a520ee3a20e3-59'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac0bafdf964a5206e9420e3',
#        'name': 'UvA Roeterseilandcomplex',
#        'location': {'address': 'Roetersstraat 15-27',
#         'lat': 52.36333339391467,
#         'lng': 4.912032530902984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36333339391467,
#           'lng': 4.912032530902984}],
#         'distance': 1571,
#         'postalCode': '1018 WB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Roetersstraat 15-27',
#          '1018 WB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ae941735',
#          'name': 'University',
#          'pluralName': 'Universities',
#          'shortName': 'University',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac0bafdf964a5206e9420e3-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a3a8958f964a520f49f1fe3',
#        'name': 'Pakhuis De Zwijger',
#        'location': {'address': 'Piet Heinkade 179',
#         'lat': 52.376816703823806,
#         'lng': 4.922069628755049,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.376816703823806,
#           'lng': 4.922069628755049}],
#         'distance': 1656,
#         'postalCode': '1019 HC',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Piet Heinkade 179',
#          '1019 HC Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ff931735',
#          'name': 'Convention Center',
#          'pluralName': 'Convention Centers',
#          'shortName': 'Convention Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '67720914'}},
#       'referralId': 'e-0-4a3a8958f964a520f49f1fe3-61'}]}]}}

# %% [markdown]
# Before we proceed, let's borrow the __get_category_type__ function from the Foursquare

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json data and structure it into a pandas dataframe as __df_park__.

# %%
parking = results['response']['groups'][0]['items']
    
df_park = json_normalize(parking) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df_park =df_park.loc[:, filtered_columns]

# filter the category for each row
df_park['venue.categories'] = df_park.apply(get_category_type, axis=1)


# clean columns
df_park.columns = [col.split(".")[-1] for col in df_park.columns]

df_park.head()
# Out:
#                                                 name categories        lat  \
# 0                                Q-Park De Bijenkorf    Parking  52.374132
# 1  MobyPark - Parking Dam Square - Book now and p...    Parking  52.373077
# 2                                     Q-Park De Kolk    Parking  52.376267
# 3                            Parkeergarage Oosterdok    Parking  52.376147
# 4                                  Oosterdok Parking    Parking  52.376569
#
#         lng
# 0  4.894579
# 1  4.895563
# 2  4.894437
# 3  4.909100
# 4  4.905247

# %% [markdown]
# And we can print the __parking lots number__ in dataframe <br>(venues returned by Foursquare)

# %%
print('{} parking lots were returned by Foursquare.'.format(df_park.shape[0]))
# Out:
# 62 parking lots were returned by Foursquare.

# %% [markdown]
# We can save the dataframe as csv. <br>
# It is optional...

# %%
df_park.to_csv('park_amsterdam.csv')

# %% [markdown]
# __DataSet of Bus/Train Stops__
#
# We can reach __Bus/Train Stops Locations__ via Foursquare Api with _CategaoryId_. In <a href="https://developer.foursquare.com/docs/resources/categories">Foursquare</a> web site, we learned that the categoryIds as;
#
# - Light Rail Station categoryId is "4bf58dd8d48988d1fc931735"
# - Metro Station categoryId is "4bf58dd8d48988d1fd931735"
# - Tram Station categoryId is "52f2ab2ebcbc57f1066b8b51"
# - Bus Station categoryId is "4bf58dd8d48988d1fe931735"
#
#
# As we know, the important disadvantage of Foursquare API is the response limit (the number of venues returned by Foursquare API has a maximum limit is 100) of queries. Because of there are more than 100 Bus/Train Stops in Amsterdam, we tried to send query with sub-categoryIDs of venues and update the dataframe with "for loop" easily.
#
# Firstly, we create the Bus/Train Stops categoryID List:

# %%
#create the Bus/Train Stops categoryID List:
category_list=['4bf58dd8d48988d1fc931735','4bf58dd8d48988d1fd931735','52f2ab2ebcbc57f1066b8b51','4bf58dd8d48988d1fe931735'] #bus/train station
c=0
df_trans_tot=pd.DataFrame()

# %% [markdown]
# For get the more than 100 response via Foursquare, we send 4 different categoryID in a _for loop_. We create a a pandas dataframe as df_trans and update them into new a pandas dataframe as __df_trans_tot__.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 3000 # define radius

   
#Create a for loop
for c in range(len(category_list)):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    ams_latitude, 
    ams_longitude, 
    radius,
    category_list[c],
    LIMIT)
    print(url) #check the URLs
    
    #Send the GET request and examine the resutls    
    results = requests.get(url).json()  
    transportation = results['response']['groups'][0]['items']
    df_trans = json_normalize(transportation) # flatten JSON  
   
    # function that extracts the category of the venue
    def get_category_type(row):
        try:
            categories_list = row['categories']
        except:
            categories_list = row['venue.categories']

        if len(categories_list) == 0:
            return None
        else:
            return categories_list[0]['name']
    
## Now we are ready to clean the json data and structure it into a pandas dataframe as df_trans
    
    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    df_trans =df_trans.loc[:, filtered_columns]
    
    # filter the category for each row
    df_trans['venue.categories'] = df_trans.apply(get_category_type, axis=1)
    
    # clean columns
    df_trans.columns = [col.split(".")[-1] for col in df_trans.columns]

    print('For Category ID {} : {}'.format(category_list[c], df_trans.shape))
    
    # Update the dataframe
    df_trans_tot=df_trans_tot.append(df_trans).reset_index(drop=True)
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=2FORA2OSPVYW5ZDJAQRNR0PIYKV5F1MLOPLTYJHFFLMQFSN3&client_secret=CAQJ0U1OTAE0HFYS3BOEPZVPMLRAQLZGJBIUSDN2LK43J5YW&v=20180604&ll=52.3745403,4.89797550561798&radius=3000&categoryId=4bf58dd8d48988d1fc931735&limit=100
# For Category ID 4bf58dd8d48988d1fc931735 : (1, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=2FORA2OSPVYW5ZDJAQRNR0PIYKV5F1MLOPLTYJHFFLMQFSN3&client_secret=CAQJ0U1OTAE0HFYS3BOEPZVPMLRAQLZGJBIUSDN2LK43J5YW&v=20180604&ll=52.3745403,4.89797550561798&radius=3000&categoryId=4bf58dd8d48988d1fd931735&limit=100
# For Category ID 4bf58dd8d48988d1fd931735 : (16, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=2FORA2OSPVYW5ZDJAQRNR0PIYKV5F1MLOPLTYJHFFLMQFSN3&client_secret=CAQJ0U1OTAE0HFYS3BOEPZVPMLRAQLZGJBIUSDN2LK43J5YW&v=20180604&ll=52.3745403,4.89797550561798&radius=3000&categoryId=52f2ab2ebcbc57f1066b8b51&limit=100
# For Category ID 52f2ab2ebcbc57f1066b8b51 : (100, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=2FORA2OSPVYW5ZDJAQRNR0PIYKV5F1MLOPLTYJHFFLMQFSN3&client_secret=CAQJ0U1OTAE0HFYS3BOEPZVPMLRAQLZGJBIUSDN2LK43J5YW&v=20180604&ll=52.3745403,4.89797550561798&radius=3000&categoryId=4bf58dd8d48988d1fe931735&limit=100
# For Category ID 4bf58dd8d48988d1fe931735 : (53, 4)

# %% [markdown]
# Let's see the __df_trans__ dataframe

# %%
df_trans.head()
# Out:
#                                                 name   categories        lat  \
# 0                               City Sightseeing Bus  Bus Station  52.377835
# 1                                   Martelaarsgracht  Bus Station  52.377654
# 2  Busstation CS Stationsplein (C en D - GVB en C...  Bus Station  52.377502
# 3                      Busstation Amsterdam Centraal  Bus Station  52.379927
# 4                                 GVB Tickets & Info  Bus Station  52.377679
#
#         lng
# 0  4.897619
# 1  4.896091
# 2  4.901842
# 3  4.900199
# 4  4.900690

# %% [markdown]
# And we can print the total Total Light Rail/Metro/Train/Tram/Bus Station number in dataframe
# (venues returned by Foursquare with for loop)

# %%
print('Total Light Rail/Metro/Train/Tram/Bus Station is:',df_trans_tot.shape[0])
# Out:
# Total Light Rail/Metro/Train/Tram/Bus Station is: 170

# %% [markdown]
# We can save the dataframe as csv.<br>
# It is optional...

# %%
df_trans.to_csv('transportation_amsterdam.csv')

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280             0
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156             0
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757             0
# 3         Nes e.o.  Amsterdam  52.370861   4.893728             0
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584             0
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# #### 4. Arrange The DataFrames

# %% [markdown]
# Now, we have 3 different DataFrames, which are;
# - Neighborhoods (__df_amsterdam__)
# - Parking Lots Locations (__df_park__)
# - Bus/Train Stops Locations (__df_trans_tot__)
#
# In this step, we merge the dataframes.
#
# Firstly, we calculate the average distance of all "_parking lot_" for each neighborhood. While we calculate the distance, we limit the distance with two digit after decimal point.
#
# Then, we add the result to the "CarPark_Dist" column of the __df_amsterdam__ dataframe.

# %%
#Average Distance Between Parking Lots and Neighborhoods
geolocator = Nominatim(user_agent="myapplication")
n=0
m=0
dist_list=[]
while True:
    if n < df_amsterdam['Neighborhood'].count():
        for m in range(df_park['name'].count()):
            location1=list(df_amsterdam.loc[n,'Latitude':'Longitude'])
            location2=list(df_park.loc[m,'lat':'lng'])
            dist=float('%.2f' % geodesic(location1,location2).m)
            dist_list.append(dist)
        #print('{} {} is: {} meters'.format(n+1,(df_amsterdam.loc[n,'Neighborhood']),('%.2f' % mean(dist_list)))
        df_amsterdam.loc[df_amsterdam.index[n], 'CarPark_Dist'] = ('%.2f' % mean(dist_list)) #Update The Neighborhood DataFrame
        df_amsterdam['CarPark_Dist']=pd.to_numeric(df_amsterdam['CarPark_Dist']) #Change the 'CarPark Dist' Column Type as float
        n+=1
    else:
        print('The average distance of all {} parking lots calculated for all {} neighborhoods and added to df_amsterdam dataframe'.format((df_park.shape[0]), df_amsterdam.shape[0]))
        break
# Out:
# The average distance of all 62 parking lots calculated for all 479 neighborhoods and added to df_amsterdam dataframe

# %% [markdown]
# Let's see the __df_amsterdam__ dataframe

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280       1564.27
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1508.15
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757       1488.52
# 3         Nes e.o.  Amsterdam  52.370861   4.893728       1464.66
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1448.57
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# Secondly, we calculate the total 'Light Rail/Metro/Train/Tram/Bus Station number' for each neighborhood if the distance of stops below than 1.000 meters<br>
# Then, we add the result to the "Close Bus/Train" column of the __df_amsterdam__ dataframe.

# %%
#Bus/Train Station Number in Neighborhood
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.distance import geodesic
from statistics import mean
geolocator = Nominatim(user_agent="myapplication")
n=0
m=0
p=0
while True:
    if n < df_amsterdam['Neighborhood'].count():
        for m in range(df_trans_tot['name'].count()):
            location1=list(df_amsterdam.loc[n,'Latitude':'Longitude'])
            location2=list(df_trans_tot.loc[m,'lat':'lng'])
            dist=float('%.2f' % geodesic(location1,location2).m)
            if dist<=1000: #We set 1000meter distance
                p+=1
        #print(n+1, df_amsterdam.loc[n,'Neighborhood'],'has:', p, 'close bus/train stop')
        df_amsterdam.loc[df_amsterdam.index[n], 'Close_Bus/Train'] = p #Update The Neighborhood DataFrame
        n+=1
        p=0
    else:
        print('The total number of all {} close Bus/Train stops for all {} neighborhood is calculated and added to df_amsterdam dataframe'.format((df_trans_tot.shape[0]), df_amsterdam.shape[0]))
        break
# Out:
# The total number of all 170 close Bus/Train stops for all 479 neighborhood is calculated and added to df_amsterdam dataframe

# %% [markdown]
# Let's see the __df_amsterdam__ dataframe

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280       1564.27
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1508.15
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757       1488.52
# 3         Nes e.o.  Amsterdam  52.370861   4.893728       1464.66
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1448.57
#
#    Close_Bus/Train
# 0               57
# 1               61
# 2               63
# 3               55
# 4               50

# %% [markdown]
# #### 5. Comparison of Neighborhoods

# %% [markdown]
# In this step we can start to comparison of neighborhoods to determine the best suitable location for a new restaurant in Amsterdam.
# We sort the neighborhods from the average distance of parking lots and create a new dataframe as __df_comparison__ with first 20 neighborhods.

# %%
df_amsterdam=df_amsterdam.sort_values('CarPark_Dist', ascending=True).reset_index(drop=True)
df_comparison=df_amsterdam.head(20)
df_comparison
# Out:
#            Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0       BG-terrein e.o.  Amsterdam  52.369546   4.895584       1448.57
# 1              Nes e.o.  Amsterdam  52.370861   4.893728       1464.66
# 2       Burgwallen Oost  Amsterdam  52.372815   4.898757       1488.52
# 3        Kalverdriehoek  Amsterdam  52.367917   4.891315       1496.06
# 4    Stationsplein e.o.  Amsterdam  52.379658   4.900724       1498.82
# 5        Begijnhofbuurt  Amsterdam  52.370704   4.891284       1504.25
# 6     Leidsegracht Zuid  Amsterdam  52.366748   4.886283       1504.68
# 7        Reguliersbuurt  Amsterdam  52.366611   4.893200       1505.27
# 8        Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1508.15
# 9   Rembrandtpleinbuurt  Amsterdam  52.366219   4.897981       1509.86
# 10     Langestraat e.o.  Amsterdam  52.378368   4.889985       1509.94
# 11        Van Loonbuurt  Amsterdam  52.363580   4.893069       1512.70
# 12      Spuistraat Zuid  Amsterdam  52.370996   4.889218       1513.07
# 13         Gouden Bocht  Amsterdam  52.365346   4.891126       1513.39
# 14      Amstelveldbuurt  Amsterdam  52.363677   4.899009       1513.53
# 15     Oosterdokseiland  Amsterdam  52.377235   4.907918       1515.86
# 16     Leliegracht e.o.  Amsterdam  52.375521   4.887076       1516.87
# 17         Spiegelbuurt  Amsterdam  52.364895   4.887694       1517.13
# 18            Hemelrijk  Amsterdam  52.378148   4.894921       1517.57
# 19   Felix Meritisbuurt  Amsterdam  52.371329   4.885493       1517.65
#
#     Close_Bus/Train
# 0                50
# 1                55
# 2                63
# 3                33
# 4                51
# 5                37
# 6                34
# 7                29
# 8                61
# 9                30
# 10               54
# 11               30
# 12               36
# 13               33
# 14               31
# 15               50
# 16               45
# 17               35
# 18               52
# 19               29

# %% [markdown]
# Before starting to compare, we __normalize__ the data in "CarPark_Dist" and	"Close_Bus/Train" columns and create 2 new columns as _'CarPark_Dist_N'_ and _'Close_Bus/Train_N'_.

# %%
df_comparison['CarPark_Dist_N']=df_comparison['CarPark_Dist'].max()-df_comparison.CarPark_Dist
df_comparison['CarPark_Dist_N']=df_comparison['CarPark_Dist_N']/df_comparison['CarPark_Dist_N'].max()
df_comparison['Close_Bus/Train_N'] = df_comparison['Close_Bus/Train']/df_comparison['Close_Bus/Train'].max() #normalize
df_comparison
# Out:
#            Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0       BG-terrein e.o.  Amsterdam  52.369546   4.895584       1448.57
# 1              Nes e.o.  Amsterdam  52.370861   4.893728       1464.66
# 2       Burgwallen Oost  Amsterdam  52.372815   4.898757       1488.52
# 3        Kalverdriehoek  Amsterdam  52.367917   4.891315       1496.06
# 4    Stationsplein e.o.  Amsterdam  52.379658   4.900724       1498.82
# 5        Begijnhofbuurt  Amsterdam  52.370704   4.891284       1504.25
# 6     Leidsegracht Zuid  Amsterdam  52.366748   4.886283       1504.68
# 7        Reguliersbuurt  Amsterdam  52.366611   4.893200       1505.27
# 8        Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1508.15
# 9   Rembrandtpleinbuurt  Amsterdam  52.366219   4.897981       1509.86
# 10     Langestraat e.o.  Amsterdam  52.378368   4.889985       1509.94
# 11        Van Loonbuurt  Amsterdam  52.363580   4.893069       1512.70
# 12      Spuistraat Zuid  Amsterdam  52.370996   4.889218       1513.07
# 13         Gouden Bocht  Amsterdam  52.365346   4.891126       1513.39
# 14      Amstelveldbuurt  Amsterdam  52.363677   4.899009       1513.53
# 15     Oosterdokseiland  Amsterdam  52.377235   4.907918       1515.86
# 16     Leliegracht e.o.  Amsterdam  52.375521   4.887076       1516.87
# 17         Spiegelbuurt  Amsterdam  52.364895   4.887694       1517.13
# 18            Hemelrijk  Amsterdam  52.378148   4.894921       1517.57
# 19   Felix Meritisbuurt  Amsterdam  52.371329   4.885493       1517.65
#
#     Close_Bus/Train  CarPark_Dist_N  Close_Bus/Train_N
# 0                50        1.000000           0.793651
# 1                55        0.767082           0.873016
# 2                63        0.421685           1.000000
# 3                33        0.312536           0.523810
# 4                51        0.272583           0.809524
# 5                37        0.193978           0.587302
# 6                34        0.187753           0.539683
# 7                29        0.179213           0.460317
# 8                61        0.137522           0.968254
# 9                30        0.112768           0.476190
# 10               54        0.111610           0.857143
# 11               30        0.071656           0.476190
# 12               36        0.066300           0.571429
# 13               33        0.061668           0.523810
# 14               31        0.059641           0.492063
# 15               50        0.025912           0.793651
# 16               45        0.011291           0.714286
# 17               35        0.007528           0.555556
# 18               52        0.001158           0.825397
# 19               29        0.000000           0.460317

# %% [markdown]
# We can visualize the results in bar plot

# %%
df_comparison.plot.bar(x="Neighborhood", y=["CarPark_Dist_N", "Close_Bus/Train_N"],stacked=True,figsize=(16,8))
plt.xlabel('Neighborhoods') # x-label to the plot
plt.title('Comparison of Neighborhoods by Parking Lots and Bus/Train Stops') # title to the plot
plt.legend(('Parking Lots Av. Dist.', 'Close Bus/Train Stops'),loc=1) #legend of the plot
plt.show()

# %% [markdown]
# __Lastly, get the comparison result__ and save the result in a new dataframe as *df_result*

# %%
df_comparison['Total']=df_comparison['CarPark_Dist_N']+df_comparison['Close_Bus/Train_N'] #create a new column
df_result=(df_comparison[df_comparison['Total'] == df_comparison['Total'].max()]).reset_index(drop=True) #return the max value and create a 
df_result
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1448.57
#
#    Close_Bus/Train  CarPark_Dist_N  Close_Bus/Train_N     Total
# 0               50             1.0           0.793651  1.793651

# %% [markdown]
# __The result,__

# %%
print('The best neighborhood for a new restaurant in Amsterdam is : {}'.format(df_result.at[0,'Neighborhood']))
# Out:
# The best neighborhood for a new restaurant in Amsterdam is : BG-terrein e.o.

# %% [markdown]
# There detail of parking lots which are below 500 meters distance

# %%
n=0
m=0
for m in range(df_park['name'].count()):
    location1=list(df_result.loc[0,'Latitude':'Longitude'])
    location2=list(df_park.loc[m,'lat':'lng'])
    dist=float('%.2f' % geodesic(location1,location2).m)
    #dist_list.append(dist)
    if dist<500:
        n+=1
        print('Between {} and {} is {} meters'.format((df_result.loc[0,'Neighborhood']),(df_park.at[m,'name']),dist))
    else:
        continue
print('There are {} parking lots exist in {} below 500 meters distance'.format(n,df_result.at[0,'Neighborhood']))
# Out:
# Between BG-terrein e.o. and MobyPark - Parking Dam Square - Book now and pay only € 3/h! is 392.96 meters
# Between BG-terrein e.o. and Parkeergarage Geelvinck is 429.25 meters
# Between BG-terrein e.o. and Parking wijdesteeg is 457.57 meters
# Between BG-terrein e.o. and De Overkant (van MdB) is 210.57 meters
# Between BG-terrein e.o. and Parkeergarage Stadhuis-Muziektheater is 398.65 meters
# Between BG-terrein e.o. and Amstel is 303.19 meters
# Between BG-terrein e.o. and Parkking The Bank Rembrandtplein is 403.97 meters
# Between BG-terrein e.o. and Fietsenstallingen Singel is 435.3 meters
# Between BG-terrein e.o. and Dam is 386.62 meters
# Between BG-terrein e.o. and Kalverstraat is 300.41 meters
# There are 10 parking lots exist in BG-terrein e.o. below 500 meters distance

# %% [markdown]
# Finally, we can create a map of Amsterdam with;
# - The result (best neighborhood) as RED circle marker
# - Parking Lots as BLUE circle markers
# - Light Rail/Metro/Train/Tram/Bus Stations as ORANGE circle markers

# %%
result_latitude=df_result.at[0,'Latitude']
result_longitude=df_result.at[0,'Longitude']
result_name=df_result.at[0,'Neighborhood']

result_map = folium.Map(location=[ams_latitude, ams_longitude], zoom_start=14) # generate map centred around Ecco


# show neighborhood as a red circle mark
folium.features.CircleMarker(
    [result_latitude, result_longitude],
    radius=10,
    popup=result_name,
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(result_map)


# add Parking Lots to the map as blue circle markers
for lat, lng, label in zip(df_park.lat, df_park.lng, df_park.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(result_map)
    

# add Light Rail/Metro/Train/Tram/Bus Station to the map as orange circle markers
for lat, lng, label in zip(df_trans_tot.lat, df_trans_tot.lng, df_trans_tot.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='orange',
        fill_color='orange',
        fill_opacity=0.6
        ).add_to(result_map)

# display map
result_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Result of the Project:

# %% [markdown]
# As we mentioned before, in this project, we want to determine the best neighborhood in Amsterdam for the entrepreneurs to open a new restaurant. For this aim, firstly, we get the (free and public) "_boroughs and neighborhoods list_" of Amsterdam from the "Statistics Netherlands" (Centraal Bureau voor de Statistiek-CBS). In the dataset __there there are 479 neighborhoods (buurt) and 99 boroughs (wijk) exist in Amsterdam with their geolocations__. We continue to project with 479 neighborhoods list.
#
# For comparison between the neighborhoods, we need "Parking Lots" list and "Light Rail/Metro/Train/Tram/Bus Station list" with their geolocations. We get these datas via Foursquare Api. In Foursquare web site, we learned that the categoryId of our venues' (Parking, Light Rail Station, Metro Station, Tram Station and Bus Station) categoryIds and use these Ids to get and create the datasets. As we know, Foursquare API has a response limit (the number of venues returned by Foursquare API has a maximum limit is 100) of queries. Because of there are more than 100 Bus/Train Stops in Amsterdam, we tried to send query with sub-categoryIDs of venues and update the dataframe with "for loop" with 3000 meters radius easily. The result is;
# - 62 Parking Lots
# - 170 Light Rail/Metro/Train/Tram/Bus Stations
#
# Then, we calculate the average distance of all "parking lot"  for each neighborhood and calculate the total "Light Rail/Metro/Train/Tram/Bus Station number" below than 1000meters for each neighborhood. Of course, we add the result the main dataframe (df_amsterdam).
#
# Before starting to compare, we normalize the data and then sum up these two new columns and reach the result. In the project; we reach that  in "__The best neighborhood for a new restaurant in Amsterdam is : Nes e.o.__".
#
# The Nes e.o. has;
# - 55 Light Rail/Metro/Train/Tram/Bus Stations in 1000 meters distance
# - The average distance  for 62 Parking Lots is 1388.64 meters
# - There are 8 parking lots exist below 500 meters distance

# %% [markdown]
# ### Discussion about the Project:

# %% [markdown]
# As we mentioned in Introduction; "__It is only a capstone final project and it is not claimed that the result of the project is 100% proper for trade and investing industry.__" The project framework needs more thinking and planning with systematically. And also the project needs more datasets, field and market research.
#
# Firstly, distance from parking lots and train/bus stations can't be the only factor for selecting a restaurant location. We need different type of data like usage density of every streets, frequently preferred routes and the preferred reason... etc.
#
# Secondly, parking lots capacity also an important detail. Maybe a restaurant has 3 parking lots in too close distance but they haven't got enough parking lot capacity so most of time it has no free parking lot. So here 3 close parking lots couldn't add positive effect to make a decision. So, before starting to project, field research and/or the tips of parking lots also be keep in views.
#
# Thirdly, taxes are another an important factor in determining the best location. So, we need extra datasets.
#
# Also, if we know the closed/moved restaurants information in earlier, we can add these factor to the project. Although the good location (close the parking lots, stations, etc.) but people maybe don't select it because of another reason (bad smell in the area, construction in the street, closely a loud venue).
#
# So the project has insufficiencies.
#
# On the other hand, the project can be helpful in the decision process for the entrepreneurs and/or give an idea to make a comprehensive project to researchers.

# %% [markdown]
# ### Conclusion of the Project:

# %% [markdown]
# This project is a "Capstone Project" of Coursera - "IBM Applied Data Science Capstone Course". In the project, we tried to use most of the python scripts, libraries, virtualization of data, foursquare api.. etc. So our first aim is to use them in a systematically.
#
# In this project, we want to determine the best neighborhood in Amsterdam for the entrepreneurs to open a new restaurant. We compare the the 479 neighborhoods in Amsterdam with "the average distance of all parking lot" and "the total Light Rail/Metro/Train/Tram/Bus Station number below than 1000meters".
#
# After compare the neighborhoods with these two factor, we reach that "__The best neighborhood for a new restaurant in Amsterdam is : Nes e.o.__"
# <br>The Nes e.o. has;
# - 55 Light Rail/Metro/Train/Tram/Bus Stations in 1000 meters distance
# - The average distance for 62 Parking Lots is 1388.64 meters
# - There are 8 parking lots exist below 500 meters distance
#
# Although the insufficiencies (the project needs more datasets, field and market research), we think that the project give an idea to researchers to make a comprehensive project in future works.

# %% [markdown]
# ### Presentation of the Project:

# %% [markdown]
# https://prezi.com/p/3hw6a2z24w2h/best-neighborhood-to-operate-a-restaurant-in-amsterdam/
